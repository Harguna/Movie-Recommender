# %% [markdown]
# # KNN - Memory(Item) Based Collaborative Filtering

# %%
import pandas as pd
import numpy as np
import math
from math import sqrt
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.neighbors import NearestNeighbors

# %%
import numpy as np

# %%
sampled_ratings=pd.read_csv("data/final_sr_red.csv") #reading csv sample rating
#sampled_ratings.drop("bin",axis=1, inplace=True)
sr=sampled_ratings

# %% [markdown]
# ## Challenges with KNN:
#
# ## We face a lot of challenges with the knn model.
#
# ## 1. Runtime:  We use a KNN brute for algorithm to fill out martrix. We have 1000 X 137232 ratings to fill. Computing predictions for so many item-user pairs takes too long. This is a limitation of our model. To overcome this limitation, we evaluate our model/ tune parameters as discussed.

# %% [markdown]
# ### We split of sampled data into a 80-20 train-validation split. To do this, we first create a pivot matrix of the enire sample data. We then unstack the pivoted data back to the original structure and randomly select 20% of the ratings as part of our validation set. We then remove these ratings in our pivot, fit our model on the train dataset, and try to predict these ratings in order to validate our model and tune our hyper-parameter 'k'.

# %% [markdown]
# ## 2. Sparse matrix: Finding user similarity was difficult due to lack of values

# %%
#Pivoting sampled rating for KNN
sr = sr.pivot(
    index='movieId',
    columns='userId',
    values='rating'
).fillna(0)

# %%
# Unstacking the pivot
sr_test_list = sr.unstack().reset_index(name="rating").set_index("movieId")
sr_test_list = sr_test_list[sr_test_list.rating>0]

# %%
sr_test_list.shape
# Out:
# (916037, 2)

# %%
#splitting unstacked df into train-validation set
x, sr_test_rem = tts(sr_test_list, test_size=0.2, random_state = 69)

# %%
len(sr_test_rem)
# Out:
# 183208

# %%
# setting our validation set ratings to 0(substitute for NA) 
a = list(sr_test_rem.index)
b = list(sr_test_rem.loc[:, "userId"])

for i in range(len(a)):
    sr.at[a[i],b[i]]=0

# %%
def goodness_of_fit(predictions,ratings):
    avg = np.mean(ratings)
    ss_res = 0
    for i in range(len(predictions)):
        err = (ratings[i]-predictions[i])**2
        ss_res += err
    ss_tot = 0
    for i in range(len(ratings)):
        ss_tot += (ratings[i]-avg)**2
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
def fit_model(k):
    model_knn = NearestNeighbors(metric='cosine',algorithm='brute', n_neighbors=k, n_jobs=-1)
    model_knn.fit(sr)
    return model_knn
    
def recommendation(model, mid, k):
    if int(sr[sr.index == mid].sum(axis=1)) == 0:
        results = pd.DataFrame(list(zip([0]*k,[0]*k)), columns = ['sim', 'mov_id'])
    else:
        query_index=mid
        distances,indices=model.kneighbors(sr[sr.index==query_index].values.reshape(1,-1))
        ind = list(indices.flatten())
        distances = list(distances.flatten())
        sim=[]
        for i in range(len(distances)):
            sim.append(1-float(distances[i]))
        mov_ids = []
        for i in ind:
            mov_ids.append(sr.index[i])
        results = pd.DataFrame(list(zip(sim,mov_ids)), columns = ['sim', 'mov_id'])
        results = results.set_index("mov_id")
    return results

# %%
def cal_mean(s):
    count = 0
    add = 0 
    for i in range(len(s)):
        if s[i] != 0:
            add += s[i]
            count += 1
    return float(add)/(count+0.001)

def predict(mid, uid, r):
    w_sum = 0 
    sim_list = []
    if max(list(r.loc[:, "sim"]))==0:
        return cal_mean(list(sr[uid]))
    else:
        for m in list(r.index):
            if float(sr[sr.index == m][uid]) != 0.0:
                sim_list.append(float(r[r.index == m]['sim']))
                w_sum += float(sr[sr.index == m][uid])*float(r[r.index == m]['sim'])
        if sim_list == []:
            return cal_mean(list(sr[uid]))
        else:
            return w_sum/sum(sim_list)

# %%
def multi_k(k):
    model = fit_model(k)
    act = []
    pred = []
    i=0
    total = len(sr_test_rem)
    m_list = list(set(sr_test_rem.index))

    for m in m_list:
        u_list = list(sr_test_rem[sr_test_rem.index==m]['userId'])
        print(i, "of", total ,"completed")
        i=i+len(u_list)
        r = recommendation(model, m, k)
        for u in u_list:
            p = predict(m, u, r)
            act.append(float(sr_test_rem[(sr_test_rem.index == m)&(sr_test_rem['userId'] ==u)]['rating']))
            pred.append(p)
            
    r2 = goodness_of_fit(pred, act)
    rmse = sqrt(mean_squared_error(act, pred))
    mae = mean_absolute_error(act, pred)
    print(k, " - RMSE:", rmse, " - MAE:", mae, " - R squared:", r2)
    return pred, act

# %%
p, a = multi_k(48) 

data = pd.DataFrame(list(zip(p, a)), columns=['pred', 'act'])
data.to_csv("recomm_results.csv", sep=',')
# Out:
# 0 of 183208 completed
# 481 of 183208 completed
# 900 of 183208 completed
# 908 of 183208 completed
# 934 of 183208 completed
# 942 of 183208 completed
# 945 of 183208 completed
# 950 of 183208 completed
# 981 of 183208 completed
# 1914 of 183208 completed
# 2070 of 183208 completed
# 3135 of 183208 completed
# 3200 of 183208 completed
# 3237 of 183208 completed
# 3238 of 183208 completed
# 3241 of 183208 completed
# 3920 of 183208 completed
# 3931 of 183208 completed
# 4661 of 183208 completed
# 4877 of 183208 completed
# 4898 of 183208 completed
# 5176 of 183208 completed
# 5215 of 183208 completed
# 5737 of 183208 completed
# 6307 of 183208 completed
# 6477 of 183208 completed
# 6532 of 183208 completed
# 6534 of 183208 completed
# 6535 of 183208 completed
# 6546 of 183208 completed
# 7048 of 183208 completed
# 7880 of 183208 completed
# 7886 of 183208 completed
# 8008 of 183208 completed
# 8700 of 183208 completed
# 8732 of 183208 completed
# 8742 of 183208 completed
# 8851 of 183208 completed
# 9814 of 183208 completed
# 10053 of 183208 completed
# 10807 of 183208 completed
# 11003 of 183208 completed
# 11029 of 183208 completed
# 11035 of 183208 completed
# 11223 of 183208 completed
# 11494 of 183208 completed
# 11878 of 183208 completed
# 12210 of 183208 completed
# 12346 of 183208 completed
# 12348 of 183208 completed
# 12468 of 183208 completed
# 12513 of 183208 completed
# 12617 of 183208 completed
# 12868 of 183208 completed
# 12891 of 183208 completed
# 13006 of 183208 completed
# 13072 of 183208 completed
# 13080 of 183208 completed
# 13669 of 183208 completed
# 13670 of 183208 completed
# 13677 of 183208 completed
# 13685 of 183208 completed
# 14668 of 183208 completed
# 14916 of 183208 completed
# 15068 of 183208 completed
# 15098 of 183208 completed
# 15112 of 183208 completed
# 16459 of 183208 completed
# 17050 of 183208 completed
# 17216 of 183208 completed
# 17281 of 183208 completed
# 17372 of 183208 completed
# 17756 of 183208 completed
# 17757 of 183208 completed
# 17762 of 183208 completed
# 17828 of 183208 completed
# 18510 of 183208 completed
# 18522 of 183208 completed
# 18523 of 183208 completed
# 18698 of 183208 completed
# 18700 of 183208 completed
# 19422 of 183208 completed
# 20232 of 183208 completed
# 20791 of 183208 completed
# 20951 of 183208 completed
# 20952 of 183208 completed
# 21649 of 183208 completed
# 21650 of 183208 completed
# 22472 of 183208 completed
# 23100 of 183208 completed
# 23104 of 183208 completed
# 24036 of 183208 completed
# 24044 of 183208 completed
# 24133 of 183208 completed
# 24173 of 183208 completed
# 24175 of 183208 completed
# 24751 of 183208 completed
# 25019 of 183208 completed
# 25028 of 183208 completed
# 25038 of 183208 completed
# 25039 of 183208 completed
# 25052 of 183208 completed
# 25054 of 183208 completed
# 25172 of 183208 completed
# 25189 of 183208 completed
# 25346 of 183208 completed
# 25547 of 183208 completed
# 25577 of 183208 completed
# 26107 of 183208 completed
# 26173 of 183208 completed
# 26266 of 183208 completed
# 27466 of 183208 completed
# 27887 of 183208 completed
# 28694 of 183208 completed
# 29937 of 183208 completed
# 30008 of 183208 completed
# 30083 of 183208 completed
# 30586 of 183208 completed
# 31173 of 183208 completed
# 31217 of 183208 completed
# 32367 of 183208 completed
# 33325 of 183208 completed
# 33371 of 183208 completed
# 33471 of 183208 completed
# 33474 of 183208 completed
# 33475 of 183208 completed
# 33507 of 183208 completed
# 33749 of 183208 completed
# 34369 of 183208 completed
# 34702 of 183208 completed
# 35611 of 183208 completed
# 35863 of 183208 completed
# 35874 of 183208 completed
# 35973 of 183208 completed
# 36353 of 183208 completed
# 36375 of 183208 completed
# 36376 of 183208 completed
# 37429 of 183208 completed
# 37430 of 183208 completed
# 37435 of 183208 completed
# 37437 of 183208 completed
# 37470 of 183208 completed
# 37549 of 183208 completed
# 37585 of 183208 completed
# 37604 of 183208 completed
# 37608 of 183208 completed
# 37610 of 183208 completed
# 37795 of 183208 completed
# 37798 of 183208 completed
# 37869 of 183208 completed
# 37880 of 183208 completed
# 38016 of 183208 completed
# 38717 of 183208 completed
# 39255 of 183208 completed
# 39265 of 183208 completed
# 39266 of 183208 completed
# 40125 of 183208 completed
# 40212 of 183208 completed
# 40575 of 183208 completed
# 41445 of 183208 completed
# 41951 of 183208 completed
# 42062 of 183208 completed
# 42114 of 183208 completed
# 42123 of 183208 completed
# 42681 of 183208 completed
# 42684 of 183208 completed
# 43685 of 183208 completed
# 43693 of 183208 completed
# 43709 of 183208 completed
# 44728 of 183208 completed
# 44820 of 183208 completed
# 45405 of 183208 completed
# 45805 of 183208 completed
# 46101 of 183208 completed
# 46109 of 183208 completed
# 46402 of 183208 completed
# 46404 of 183208 completed
# 46460 of 183208 completed
# 46562 of 183208 completed
# 47047 of 183208 completed
# 47343 of 183208 completed
# 47391 of 183208 completed
# 47534 of 183208 completed
# 48279 of 183208 completed
# 48285 of 183208 completed
# 48304 of 183208 completed
# 48837 of 183208 completed
# 48934 of 183208 completed
# 49339 of 183208 completed
# 49340 of 183208 completed
# 49572 of 183208 completed
# 49641 of 183208 completed
# 49645 of 183208 completed
# 49764 of 183208 completed
# 49774 of 183208 completed
# 49891 of 183208 completed
# 50363 of 183208 completed
# 50368 of 183208 completed
# 50453 of 183208 completed
# 50536 of 183208 completed
# 51044 of 183208 completed
# 51047 of 183208 completed
# 51068 of 183208 completed
# 51074 of 183208 completed
# 51788 of 183208 completed
# 51796 of 183208 completed
# 51804 of 183208 completed
# 51832 of 183208 completed
# 51844 of 183208 completed
# 52434 of 183208 completed
# 53070 of 183208 completed
# 53073 of 183208 completed
# 53166 of 183208 completed
# 53210 of 183208 completed
# 53430 of 183208 completed
# 54563 of 183208 completed
# 54671 of 183208 completed
# 56315 of 183208 completed
# 56316 of 183208 completed
# 56635 of 183208 completed
# 56975 of 183208 completed
# 57849 of 183208 completed
# 58077 of 183208 completed
# 58232 of 183208 completed
# 58235 of 183208 completed
# 58259 of 183208 completed
# 58262 of 183208 completed
# 58274 of 183208 completed
# 58279 of 183208 completed
# 58474 of 183208 completed
# 58754 of 183208 completed
# 59786 of 183208 completed
# 59791 of 183208 completed
# 59954 of 183208 completed
# 59992 of 183208 completed
# 60457 of 183208 completed
# 60458 of 183208 completed
# 60469 of 183208 completed
# 60620 of 183208 completed
# 60741 of 183208 completed
# 60763 of 183208 completed
# 60842 of 183208 completed
# 60996 of 183208 completed
# 61037 of 183208 completed
# 61040 of 183208 completed
# 61064 of 183208 completed
# 61065 of 183208 completed
# 61066 of 183208 completed
# 61067 of 183208 completed
# 61069 of 183208 completed
# 61124 of 183208 completed
# 61172 of 183208 completed
# 61392 of 183208 completed
# 62126 of 183208 completed
# 62155 of 183208 completed
# 62306 of 183208 completed
# 63142 of 183208 completed
# 63143 of 183208 completed
# 63149 of 183208 completed
# 63176 of 183208 completed
# 63183 of 183208 completed
# 63186 of 183208 completed
# 63236 of 183208 completed
# 63237 of 183208 completed
# 63240 of 183208 completed
# 63285 of 183208 completed
# 64882 of 183208 completed
# 64933 of 183208 completed
# 64934 of 183208 completed
# 64939 of 183208 completed
# 65468 of 183208 completed
# 67159 of 183208 completed
# 67160 of 183208 completed
# 67613 of 183208 completed
# 67925 of 183208 completed
# 69072 of 183208 completed
# 69778 of 183208 completed
# 69779 of 183208 completed
# 69788 of 183208 completed
# 70011 of 183208 completed
# 70397 of 183208 completed
# 70625 of 183208 completed
# 70676 of 183208 completed
# 70809 of 183208 completed
# 70834 of 183208 completed
# 70847 of 183208 completed
# 70852 of 183208 completed
# 70932 of 183208 completed
# 71842 of 183208 completed
# 72152 of 183208 completed
# 73018 of 183208 completed
# 73021 of 183208 completed
# 73056 of 183208 completed
# 73088 of 183208 completed
# 73089 of 183208 completed
# 73260 of 183208 completed
# 73278 of 183208 completed
# 73329 of 183208 completed
# 73331 of 183208 completed
# 73332 of 183208 completed
# 73358 of 183208 completed
# 73373 of 183208 completed
# 73374 of 183208 completed
# 73378 of 183208 completed
# 73521 of 183208 completed
# 73534 of 183208 completed
# 73555 of 183208 completed
# 73571 of 183208 completed
# 73576 of 183208 completed
# 73608 of 183208 completed
# 73610 of 183208 completed
# 73612 of 183208 completed
# 73613 of 183208 completed
# 74020 of 183208 completed
# 74746 of 183208 completed
# 75241 of 183208 completed
# 75242 of 183208 completed
# 75254 of 183208 completed
# 75258 of 183208 completed
# 75273 of 183208 completed
# 75675 of 183208 completed
# 75708 of 183208 completed
# 75729 of 183208 completed
# 75731 of 183208 completed
# 76958 of 183208 completed
# 76970 of 183208 completed
# 76992 of 183208 completed
# 76993 of 183208 completed
# 77240 of 183208 completed
# 77340 of 183208 completed
# 77743 of 183208 completed
# 77774 of 183208 completed
# 78345 of 183208 completed
# 78354 of 183208 completed
# 78359 of 183208 completed
# 78361 of 183208 completed
# 78362 of 183208 completed
# 78809 of 183208 completed
# 79820 of 183208 completed
# 79823 of 183208 completed
# 79825 of 183208 completed
# 80276 of 183208 completed
# 80285 of 183208 completed
# 80788 of 183208 completed
# 80795 of 183208 completed
# 80799 of 183208 completed
# 80800 of 183208 completed
# 81186 of 183208 completed
# 81847 of 183208 completed
# 81952 of 183208 completed
# 82478 of 183208 completed
# 82524 of 183208 completed
# 82538 of 183208 completed
# 82578 of 183208 completed
# 82598 of 183208 completed
# 82672 of 183208 completed
# 82681 of 183208 completed
# 82804 of 183208 completed
# 82814 of 183208 completed
# 82868 of 183208 completed
# 82869 of 183208 completed
# 83012 of 183208 completed
# 83015 of 183208 completed
# 83066 of 183208 completed
# 83080 of 183208 completed
# 83108 of 183208 completed
# 83109 of 183208 completed
# 83110 of 183208 completed
# 83155 of 183208 completed
# 83302 of 183208 completed
# 83359 of 183208 completed
# 83384 of 183208 completed
# 83435 of 183208 completed
# 83835 of 183208 completed
# 84314 of 183208 completed
# 84321 of 183208 completed
# 84323 of 183208 completed
# 84324 of 183208 completed
# 84325 of 183208 completed
# 85045 of 183208 completed
# 85120 of 183208 completed
# 85122 of 183208 completed
# 85260 of 183208 completed
# 85266 of 183208 completed
# 85286 of 183208 completed
# 85633 of 183208 completed
# 86261 of 183208 completed
# 86262 of 183208 completed
# 86803 of 183208 completed
# 87460 of 183208 completed
# 87622 of 183208 completed
# 87628 of 183208 completed
# 87978 of 183208 completed
# 88100 of 183208 completed
# 88221 of 183208 completed
# 88263 of 183208 completed
# 88589 of 183208 completed
# 88607 of 183208 completed
# 88608 of 183208 completed
# 88615 of 183208 completed
# 88616 of 183208 completed
# 88639 of 183208 completed
# 88647 of 183208 completed
# 88648 of 183208 completed
# 90011 of 183208 completed
# 90038 of 183208 completed
# 90186 of 183208 completed
# 90257 of 183208 completed
# 90332 of 183208 completed
# 90352 of 183208 completed
# 90985 of 183208 completed
# 91239 of 183208 completed
# 91356 of 183208 completed
# 91704 of 183208 completed
# 91710 of 183208 completed
# 92144 of 183208 completed
# 92145 of 183208 completed
# 92147 of 183208 completed
# 92239 of 183208 completed
# 92328 of 183208 completed
# 92336 of 183208 completed
# 92337 of 183208 completed
# 92363 of 183208 completed
# 92414 of 183208 completed
# 92415 of 183208 completed
# 92437 of 183208 completed
# 92438 of 183208 completed
# 92713 of 183208 completed
# 92714 of 183208 completed
# 93416 of 183208 completed
# 93418 of 183208 completed
# 93519 of 183208 completed
# 93556 of 183208 completed
# 93558 of 183208 completed
# 93791 of 183208 completed
# 93794 of 183208 completed
# 94433 of 183208 completed
# 94712 of 183208 completed
# 95271 of 183208 completed
# 95273 of 183208 completed
# 95274 of 183208 completed
# 95293 of 183208 completed
# 95299 of 183208 completed
# 95300 of 183208 completed
# 96206 of 183208 completed
# 96758 of 183208 completed
# 97374 of 183208 completed
# 97461 of 183208 completed
# 97463 of 183208 completed
# 97471 of 183208 completed
# 97956 of 183208 completed
# 98071 of 183208 completed
# 98075 of 183208 completed
# 98090 of 183208 completed
# 98095 of 183208 completed
# 98140 of 183208 completed
# 98247 of 183208 completed
# 98318 of 183208 completed
# 98320 of 183208 completed
# 98321 of 183208 completed
# 98327 of 183208 completed
# 98450 of 183208 completed
# 98544 of 183208 completed
# 98926 of 183208 completed
# 99085 of 183208 completed
# 99102 of 183208 completed
# 100203 of 183208 completed
# 101034 of 183208 completed
# 101316 of 183208 completed
# 101369 of 183208 completed
# 101378 of 183208 completed
# 102232 of 183208 completed
# 103431 of 183208 completed
# 103619 of 183208 completed
# 103634 of 183208 completed
# 103765 of 183208 completed
# 103911 of 183208 completed
# 103912 of 183208 completed
# 103915 of 183208 completed
# 103919 of 183208 completed
# 104150 of 183208 completed
# 104848 of 183208 completed
# 104876 of 183208 completed
# 105159 of 183208 completed
# 105643 of 183208 completed
# 105718 of 183208 completed
# 105721 of 183208 completed
# 105859 of 183208 completed
# 106252 of 183208 completed
# 106257 of 183208 completed
# 107114 of 183208 completed
# 107868 of 183208 completed
# 107869 of 183208 completed
# 108374 of 183208 completed
# 108385 of 183208 completed
# 108389 of 183208 completed
# 108550 of 183208 completed
# 108557 of 183208 completed
# 108558 of 183208 completed
# 110366 of 183208 completed
# 111872 of 183208 completed
# 112027 of 183208 completed
# 112731 of 183208 completed
# 112936 of 183208 completed
# 112999 of 183208 completed
# 113000 of 183208 completed
# 113002 of 183208 completed
# 113003 of 183208 completed
# 113251 of 183208 completed
# 113800 of 183208 completed
# 114262 of 183208 completed
# 114616 of 183208 completed
# 114664 of 183208 completed
# 115834 of 183208 completed
# 115891 of 183208 completed
# 117135 of 183208 completed
# 117266 of 183208 completed
# 117549 of 183208 completed
# 117553 of 183208 completed
# 118034 of 183208 completed
# 118232 of 183208 completed
# 118235 of 183208 completed
# 118279 of 183208 completed
# 118318 of 183208 completed
# 118561 of 183208 completed
# 120272 of 183208 completed
# 121082 of 183208 completed
# 121087 of 183208 completed
# 122058 of 183208 completed
# 122074 of 183208 completed
# 122688 of 183208 completed
# 124078 of 183208 completed
# 124123 of 183208 completed
# 124724 of 183208 completed
# 124732 of 183208 completed
# 124760 of 183208 completed
# 125101 of 183208 completed
# 125642 of 183208 completed
# 125648 of 183208 completed
# 125657 of 183208 completed
# 126584 of 183208 completed
# 126586 of 183208 completed
# 126587 of 183208 completed
# 127205 of 183208 completed
# 127224 of 183208 completed
# 127249 of 183208 completed
# 128222 of 183208 completed
# 128223 of 183208 completed
# 128255 of 183208 completed
# 129854 of 183208 completed
# 129891 of 183208 completed
# 129977 of 183208 completed
# 129978 of 183208 completed
# 129979 of 183208 completed
# 129980 of 183208 completed
# 129981 of 183208 completed
# 129984 of 183208 completed
# 130128 of 183208 completed
# 130138 of 183208 completed
# 130151 of 183208 completed
# 130152 of 183208 completed
# 130509 of 183208 completed
# 131738 of 183208 completed
# 132098 of 183208 completed
# 132472 of 183208 completed
# 132513 of 183208 completed
# 132935 of 183208 completed
# 132937 of 183208 completed
# 133070 of 183208 completed
# 133072 of 183208 completed
# 133107 of 183208 completed
# 133109 of 183208 completed
# 133110 of 183208 completed
# 133171 of 183208 completed
# 133316 of 183208 completed
# 133404 of 183208 completed
# 134082 of 183208 completed
# 134990 of 183208 completed
# 134991 of 183208 completed
# 134993 of 183208 completed
# 135753 of 183208 completed
# 135760 of 183208 completed
# 135871 of 183208 completed
# 136055 of 183208 completed
# 136056 of 183208 completed
# 136557 of 183208 completed
# 136594 of 183208 completed
# 136599 of 183208 completed
# 137583 of 183208 completed
# 137670 of 183208 completed
# 138415 of 183208 completed
# 138469 of 183208 completed
# 138477 of 183208 completed
# 139457 of 183208 completed
# 139459 of 183208 completed
# 139478 of 183208 completed
# 139479 of 183208 completed
# 140794 of 183208 completed
# 140813 of 183208 completed
# 142096 of 183208 completed
# 143166 of 183208 completed
# 143169 of 183208 completed
# 143172 of 183208 completed
# 143229 of 183208 completed
# 143339 of 183208 completed
# 143363 of 183208 completed
# 143462 of 183208 completed
# 143466 of 183208 completed
# 144412 of 183208 completed
# 144477 of 183208 completed
# 144479 of 183208 completed
# 144756 of 183208 completed
# 144757 of 183208 completed
# 144778 of 183208 completed
# 144789 of 183208 completed
# 144792 of 183208 completed
# 145040 of 183208 completed
# 145079 of 183208 completed
# 145445 of 183208 completed
# 145446 of 183208 completed
# 145524 of 183208 completed
# 145570 of 183208 completed
# 145771 of 183208 completed
# 145772 of 183208 completed
# 145976 of 183208 completed
# 145977 of 183208 completed
# 146056 of 183208 completed
# 146152 of 183208 completed
# 146219 of 183208 completed
# 146225 of 183208 completed
# 146268 of 183208 completed
# 146321 of 183208 completed
# 146326 of 183208 completed
# 146937 of 183208 completed
# 147109 of 183208 completed
# 148221 of 183208 completed
# 148272 of 183208 completed
# 148274 of 183208 completed
# 148278 of 183208 completed
# 148280 of 183208 completed
# 148284 of 183208 completed
# 148296 of 183208 completed
# 148297 of 183208 completed
# 148301 of 183208 completed
# 148304 of 183208 completed
# 148319 of 183208 completed
# 148320 of 183208 completed
# 148357 of 183208 completed
# 148361 of 183208 completed
# 148363 of 183208 completed
# 148745 of 183208 completed
# 149409 of 183208 completed
# 149478 of 183208 completed
# 149481 of 183208 completed
# 149515 of 183208 completed
# 149516 of 183208 completed
# 149597 of 183208 completed
# 149627 of 183208 completed
# 149631 of 183208 completed
# 149647 of 183208 completed
# 149648 of 183208 completed
# 149690 of 183208 completed
# 149983 of 183208 completed
# 149991 of 183208 completed
# 150163 of 183208 completed
# 150166 of 183208 completed
# 150268 of 183208 completed
# 150270 of 183208 completed
# 150780 of 183208 completed
# 150782 of 183208 completed
# 150820 of 183208 completed
# 151664 of 183208 completed
# 151728 of 183208 completed
# 152273 of 183208 completed
# 152679 of 183208 completed
# 152683 of 183208 completed
# 153183 of 183208 completed
# 153585 of 183208 completed
# 153596 of 183208 completed
# 153813 of 183208 completed
# 153860 of 183208 completed
# 153862 of 183208 completed
# 153935 of 183208 completed
# 155280 of 183208 completed
# 155321 of 183208 completed
# 155323 of 183208 completed
# 156678 of 183208 completed
# 156728 of 183208 completed
# 156748 of 183208 completed
# 157611 of 183208 completed
# 158049 of 183208 completed
# 158051 of 183208 completed
# 158698 of 183208 completed
# 158707 of 183208 completed
# 159340 of 183208 completed
# 159422 of 183208 completed
# 159527 of 183208 completed
# 159540 of 183208 completed
# 159541 of 183208 completed
# 159543 of 183208 completed
# 159567 of 183208 completed
# 160576 of 183208 completed
# 161364 of 183208 completed
# 161369 of 183208 completed
# 161503 of 183208 completed
# 162004 of 183208 completed
# 162262 of 183208 completed
# 162265 of 183208 completed
# 162267 of 183208 completed
# 163123 of 183208 completed
# 163294 of 183208 completed
# 163343 of 183208 completed
# 163346 of 183208 completed
# 163350 of 183208 completed
# 164116 of 183208 completed
# 164319 of 183208 completed
# 164320 of 183208 completed
# 164323 of 183208 completed
# 164345 of 183208 completed
# 165271 of 183208 completed
# 165272 of 183208 completed
# 165463 of 183208 completed
# 165473 of 183208 completed
# 165475 of 183208 completed
# 165476 of 183208 completed
# 165488 of 183208 completed
# 165587 of 183208 completed
# 165596 of 183208 completed
# 165938 of 183208 completed
# 165940 of 183208 completed
# 165941 of 183208 completed
# 166077 of 183208 completed
# 166113 of 183208 completed
# 166120 of 183208 completed
# 166183 of 183208 completed
# 166219 of 183208 completed
# 166270 of 183208 completed
# 166271 of 183208 completed
# 166273 of 183208 completed
# 166277 of 183208 completed
# 166278 of 183208 completed
# 166377 of 183208 completed
# 166899 of 183208 completed
# 167004 of 183208 completed
# 168300 of 183208 completed
# 168340 of 183208 completed
# 168515 of 183208 completed
# 168517 of 183208 completed
# 168518 of 183208 completed
# 168525 of 183208 completed
# 168534 of 183208 completed
# 168544 of 183208 completed
# 168547 of 183208 completed
# 168583 of 183208 completed
# 168592 of 183208 completed
# 168609 of 183208 completed
# 168610 of 183208 completed
# 168624 of 183208 completed
# 168689 of 183208 completed
# 168833 of 183208 completed
# 168834 of 183208 completed
# 168837 of 183208 completed
# 168843 of 183208 completed
# 168859 of 183208 completed
# 168861 of 183208 completed
# 169173 of 183208 completed
# 169385 of 183208 completed
# 169388 of 183208 completed
# 169397 of 183208 completed
# 169401 of 183208 completed
# 169402 of 183208 completed
# 169403 of 183208 completed
# 169404 of 183208 completed
# 169488 of 183208 completed
# 169493 of 183208 completed
# 169495 of 183208 completed
# 169509 of 183208 completed
# 169627 of 183208 completed
# 169628 of 183208 completed
# 169652 of 183208 completed
# 170528 of 183208 completed
# 170533 of 183208 completed
# 170541 of 183208 completed
# 170551 of 183208 completed
# 170580 of 183208 completed
# 170685 of 183208 completed
# 171277 of 183208 completed
# 171363 of 183208 completed
# 172199 of 183208 completed
# 172206 of 183208 completed
# 172229 of 183208 completed
# 172262 of 183208 completed
# 172264 of 183208 completed
# 172268 of 183208 completed
# 172286 of 183208 completed
# 172859 of 183208 completed
# 173296 of 183208 completed
# 173316 of 183208 completed
# 173570 of 183208 completed
# 173655 of 183208 completed
# 174136 of 183208 completed
# 174161 of 183208 completed
# 174266 of 183208 completed
# 174348 of 183208 completed
# 174749 of 183208 completed
# 174751 of 183208 completed
# 176073 of 183208 completed
# 176540 of 183208 completed
# 176546 of 183208 completed
# 177781 of 183208 completed
# 178020 of 183208 completed
# 178564 of 183208 completed
# 178761 of 183208 completed
# 178904 of 183208 completed
# 179132 of 183208 completed
# 180355 of 183208 completed
# 180356 of 183208 completed
# 180403 of 183208 completed
# 180436 of 183208 completed
# 180438 of 183208 completed
# 180440 of 183208 completed
# 180442 of 183208 completed
# 180445 of 183208 completed
# 180461 of 183208 completed
# 181784 of 183208 completed
# 181981 of 183208 completed
# 182144 of 183208 completed
# 182148 of 183208 completed
# 182299 of 183208 completed
# 182623 of 183208 completed
# 182628 of 183208 completed
# 182659 of 183208 completed
# 183113 of 183208 completed
# 183118 of 183208 completed
# 183133 of 183208 completed
# 183134 of 183208 completed
# 183140 of 183208 completed
# 48  - RMSE: 0.924310909386484  - MAE: 0.7045150489189186  - R squared: 0.196771401530346

# %% [markdown]
# ### After testing different k values: 8,16,32,48,64 we tune hyper-parameter 'k' to 48, considering our results for RMSE, R squared and MAE, plus a time trade-off (the amount of time our model takes to predict ratings, considering different values of k).
#
# When k=48, we see that RMSE = 0.924, MAE = .704, R-squared = .196, time taken = 3 hours
#
# When k=64, we see that RMSE = .922, MAE = .705, R-squared = .2, time taken = 5 hours
#
# When k=32, we see that RMSE = .93, MAE = .707, R-squared = .183, time taken = 1.5 hours
#
# When k=16, we see that RMSE = .963, MAE = .727, R-squared = .126, time taken = 40 mins
#
# When k=08, we see that RMSE = 1.03, MAE = .77, R-squared = 0.003, time taken = 15-20 mins

# %%
data.head()
# Out:
#        pred  act
# 0  3.716396  2.5
# 1  3.161233  3.0
# 2  3.651837  3.0
# 3  3.886723  3.5
# 4  3.478329  3.0
