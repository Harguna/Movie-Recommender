# %% [markdown]
# ### In this notebook, we make recommendations and compute the coverage of the predictions made by our item-based KNN recommender system. To accomplish this, since we need to fill out the entire user-item matrix to find the top 5 rated by them. This dataset has only 100 users and 848 movies, where there are 25462 ratings present in the ratings dataset. We will fill in this matrix and then make 5 recommendations to a user and compute the catalog coverage. We choose a k-value of 48 for KNN since this almost gave us the best results while taking significantly lesser time than when k was 64 (which gave us the best results).

# %%
import pandas as pd
import numpy as np
import math
from math import sqrt
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# # Recommendations

# %%
pred_rating = pd.read_csv("data/reduced_final_sr.csv")

# %%
pr = pred_rating.pivot(
    index='movieId',
    columns='userId',
    values='rating'
).fillna(0)

# %%
sr_test_list = pr.unstack().reset_index(name="rating").set_index("movieId")
sr_test_list = sr_test_list[sr_test_list.rating==0]

# %%
sr_test_list.shape
# Out:
# (58490, 2)

# %%
sr_test_rem = sr_test_list

# %%
def fit_model(k):
    model_knn = NearestNeighbors(metric='cosine',algorithm='brute', n_neighbors=k, n_jobs=-1)
    model_knn.fit(pr)
    return model_knn
    
def recommendation(model, mid, k):
    if int(pr[pr.index == mid].sum(axis=1)) == 0:
        results = pd.DataFrame(list(zip([0]*k,[0]*k)), columns = ['sim', 'mov_id'])
    else:
        query_index=mid
        distances,indices=model.kneighbors(pr[pr.index==query_index].values.reshape(1,-1))
        ind = list(indices.flatten())
        distances = list(distances.flatten())
        sim=[]
        for i in range(len(distances)):
            sim.append(1-float(distances[i]))
        mov_ids = []
        for i in ind:
            mov_ids.append(pr.index[i])
        results = pd.DataFrame(list(zip(sim,mov_ids)), columns = ['sim', 'mov_id'])
        results = results.set_index("mov_id")
    return results

# %%
def cal_mean(s):
    count = 0
    add = 0 
    for i in range(len(s)):
        if s[i] != 0:
            add += s[i]
            count += 1
    return float(add)/(count+0.001)

def predict(mid, uid, r):
    w_sum = 0 
    sim_list = []
    if max(list(r.loc[:, "sim"]))==0:
        return cal_mean(list(pr[uid]))
    else:
        for m in list(r.index):
            if float(pr[pr.index == m][uid]) != 0.0:
                sim_list.append(float(r[r.index == m]['sim']))
                w_sum += float(pr[pr.index == m][uid])*float(r[r.index == m]['sim'])
        if sim_list == []:
            return cal_mean(list(pr[uid]))
        else:
            return w_sum/sum(sim_list)

# %%
def multi_k(k):
    model = fit_model(k)
    total = len(sr_test_rem)
    m_list = list(set(sr_test_rem.index))
    i=0

    for m in m_list:
        u_list = list(sr_test_rem[sr_test_rem.index==m]['userId'])
        print(i, "of", total ,"completed")
        i=i+len(u_list)
        r = recommendation(model, m, k)
        for u in u_list:
            p = predict(m, u, r)
            pr.at[m,u] = p

# %%
multi_k(48)
# Out:
# 0 of 58490 completed
# 95 of 58490 completed
# 190 of 58490 completed
# 230 of 58490 completed
# 316 of 58490 completed
# 408 of 58490 completed
# 443 of 58490 completed
# 537 of 58490 completed
# 615 of 58490 completed
# 646 of 58490 completed
# 717 of 58490 completed
# 786 of 58490 completed
# 799 of 58490 completed
# 880 of 58490 completed
# 971 of 58490 completed
# 1069 of 58490 completed
# 1153 of 58490 completed
# 1192 of 58490 completed
# 1217 of 58490 completed
# 1314 of 58490 completed
# 1364 of 58490 completed
# 1438 of 58490 completed
# 1528 of 58490 completed
# 1609 of 58490 completed
# 1668 of 58490 completed
# 1766 of 58490 completed
# 1864 of 58490 completed
# 1924 of 58490 completed
# 1957 of 58490 completed
# 1980 of 58490 completed
# 2076 of 58490 completed
# 2106 of 58490 completed
# 2204 of 58490 completed
# 2231 of 58490 completed
# 2325 of 58490 completed
# 2353 of 58490 completed
# 2410 of 58490 completed
# 2504 of 58490 completed
# 2580 of 58490 completed
# 2632 of 58490 completed
# 2653 of 58490 completed
# 2699 of 58490 completed
# 2759 of 58490 completed
# 2857 of 58490 completed
# 2877 of 58490 completed
# 2953 of 58490 completed
# 3044 of 58490 completed
# 3105 of 58490 completed
# 3168 of 58490 completed
# 3215 of 58490 completed
# 3257 of 58490 completed
# 3332 of 58490 completed
# 3428 of 58490 completed
# 3508 of 58490 completed
# 3591 of 58490 completed
# 3660 of 58490 completed
# 3750 of 58490 completed
# 3810 of 58490 completed
# 3870 of 58490 completed
# 3938 of 58490 completed
# 4030 of 58490 completed
# 4128 of 58490 completed
# 4149 of 58490 completed
# 4243 of 58490 completed
# 4341 of 58490 completed
# 4361 of 58490 completed
# 4411 of 58490 completed
# 4471 of 58490 completed
# 4562 of 58490 completed
# 4642 of 58490 completed
# 4651 of 58490 completed
# 4676 of 58490 completed
# 4728 of 58490 completed
# 4795 of 58490 completed
# 4861 of 58490 completed
# 4959 of 58490 completed
# 5056 of 58490 completed
# 5090 of 58490 completed
# 5186 of 58490 completed
# 5263 of 58490 completed
# 5354 of 58490 completed
# 5384 of 58490 completed
# 5482 of 58490 completed
# 5540 of 58490 completed
# 5565 of 58490 completed
# 5595 of 58490 completed
# 5628 of 58490 completed
# 5702 of 58490 completed
# 5738 of 58490 completed
# 5835 of 58490 completed
# 5858 of 58490 completed
# 5895 of 58490 completed
# 5993 of 58490 completed
# 6083 of 58490 completed
# 6101 of 58490 completed
# 6181 of 58490 completed
# 6250 of 58490 completed
# 6346 of 58490 completed
# 6376 of 58490 completed
# 6469 of 58490 completed
# 6520 of 58490 completed
# 6608 of 58490 completed
# 6706 of 58490 completed
# 6804 of 58490 completed
# 6890 of 58490 completed
# 6983 of 58490 completed
# 7072 of 58490 completed
# 7139 of 58490 completed
# 7237 of 58490 completed
# 7292 of 58490 completed
# 7352 of 58490 completed
# 7438 of 58490 completed
# 7476 of 58490 completed
# 7551 of 58490 completed
# 7606 of 58490 completed
# 7624 of 58490 completed
# 7667 of 58490 completed
# 7765 of 58490 completed
# 7788 of 58490 completed
# 7806 of 58490 completed
# 7904 of 58490 completed
# 7989 of 58490 completed
# 8070 of 58490 completed
# 8102 of 58490 completed
# 8125 of 58490 completed
# 8204 of 58490 completed
# 8219 of 58490 completed
# 8236 of 58490 completed
# 8310 of 58490 completed
# 8382 of 58490 completed
# 8480 of 58490 completed
# 8573 of 58490 completed
# 8655 of 58490 completed
# 8703 of 58490 completed
# 8749 of 58490 completed
# 8776 of 58490 completed
# 8805 of 58490 completed
# 8862 of 58490 completed
# 8954 of 58490 completed
# 9024 of 58490 completed
# 9062 of 58490 completed
# 9153 of 58490 completed
# 9176 of 58490 completed
# 9271 of 58490 completed
# 9368 of 58490 completed
# 9452 of 58490 completed
# 9526 of 58490 completed
# 9609 of 58490 completed
# 9692 of 58490 completed
# 9789 of 58490 completed
# 9844 of 58490 completed
# 9941 of 58490 completed
# 10035 of 58490 completed
# 10113 of 58490 completed
# 10199 of 58490 completed
# 10229 of 58490 completed
# 10262 of 58490 completed
# 10359 of 58490 completed
# 10388 of 58490 completed
# 10468 of 58490 completed
# 10506 of 58490 completed
# 10601 of 58490 completed
# 10634 of 58490 completed
# 10725 of 58490 completed
# 10796 of 58490 completed
# 10870 of 58490 completed
# 10890 of 58490 completed
# 10912 of 58490 completed
# 11007 of 58490 completed
# 11024 of 58490 completed
# 11121 of 58490 completed
# 11212 of 58490 completed
# 11240 of 58490 completed
# 11299 of 58490 completed
# 11326 of 58490 completed
# 11424 of 58490 completed
# 11465 of 58490 completed
# 11501 of 58490 completed
# 11592 of 58490 completed
# 11690 of 58490 completed
# 11787 of 58490 completed
# 11836 of 58490 completed
# 11934 of 58490 completed
# 12000 of 58490 completed
# 12095 of 58490 completed
# 12152 of 58490 completed
# 12186 of 58490 completed
# 12284 of 58490 completed
# 12307 of 58490 completed
# 12387 of 58490 completed
# 12485 of 58490 completed
# 12537 of 58490 completed
# 12565 of 58490 completed
# 12655 of 58490 completed
# 12735 of 58490 completed
# 12770 of 58490 completed
# 12842 of 58490 completed
# 12939 of 58490 completed
# 12976 of 58490 completed
# 13025 of 58490 completed
# 13114 of 58490 completed
# 13204 of 58490 completed
# 13297 of 58490 completed
# 13392 of 58490 completed
# 13447 of 58490 completed
# 13538 of 58490 completed
# 13599 of 58490 completed
# 13678 of 58490 completed
# 13744 of 58490 completed
# 13781 of 58490 completed
# 13810 of 58490 completed
# 13894 of 58490 completed
# 13988 of 58490 completed
# 14086 of 58490 completed
# 14111 of 58490 completed
# 14196 of 58490 completed
# 14293 of 58490 completed
# 14376 of 58490 completed
# 14464 of 58490 completed
# 14496 of 58490 completed
# 14517 of 58490 completed
# 14608 of 58490 completed
# 14689 of 58490 completed
# 14786 of 58490 completed
# 14870 of 58490 completed
# 14917 of 58490 completed
# 14929 of 58490 completed
# 14995 of 58490 completed
# 15007 of 58490 completed
# 15056 of 58490 completed
# 15099 of 58490 completed
# 15159 of 58490 completed
# 15215 of 58490 completed
# 15312 of 58490 completed
# 15326 of 58490 completed
# 15414 of 58490 completed
# 15510 of 58490 completed
# 15601 of 58490 completed
# 15698 of 58490 completed
# 15793 of 58490 completed
# 15841 of 58490 completed
# 15897 of 58490 completed
# 15915 of 58490 completed
# 16004 of 58490 completed
# 16076 of 58490 completed
# 16153 of 58490 completed
# 16180 of 58490 completed
# 16278 of 58490 completed
# 16372 of 58490 completed
# 16418 of 58490 completed
# 16509 of 58490 completed
# 16563 of 58490 completed
# 16632 of 58490 completed
# 16730 of 58490 completed
# 16812 of 58490 completed
# 16869 of 58490 completed
# 16956 of 58490 completed
# 17051 of 58490 completed
# 17146 of 58490 completed
# 17242 of 58490 completed
# 17311 of 58490 completed
# 17391 of 58490 completed
# 17443 of 58490 completed
# 17470 of 58490 completed
# 17544 of 58490 completed
# 17607 of 58490 completed
# 17623 of 58490 completed
# 17721 of 58490 completed
# 17812 of 58490 completed
# 17893 of 58490 completed
# 17991 of 58490 completed
# 18084 of 58490 completed
# 18179 of 58490 completed
# 18276 of 58490 completed
# 18342 of 58490 completed
# 18437 of 58490 completed
# 18520 of 58490 completed
# 18531 of 58490 completed
# 18609 of 58490 completed
# 18706 of 58490 completed
# 18798 of 58490 completed
# 18834 of 58490 completed
# 18927 of 58490 completed
# 18935 of 58490 completed
# 18960 of 58490 completed
# 18976 of 58490 completed
# 19020 of 58490 completed
# 19046 of 58490 completed
# 19136 of 58490 completed
# 19181 of 58490 completed
# 19240 of 58490 completed
# 19287 of 58490 completed
# 19371 of 58490 completed
# 19457 of 58490 completed
# 19540 of 58490 completed
# 19600 of 58490 completed
# 19692 of 58490 completed
# 19752 of 58490 completed
# 19768 of 58490 completed
# 19813 of 58490 completed
# 19835 of 58490 completed
# 19916 of 58490 completed
# 19996 of 58490 completed
# 20094 of 58490 completed
# 20192 of 58490 completed
# 20242 of 58490 completed
# 20329 of 58490 completed
# 20408 of 58490 completed
# 20506 of 58490 completed
# 20591 of 58490 completed
# 20689 of 58490 completed
# 20776 of 58490 completed
# 20867 of 58490 completed
# 20922 of 58490 completed
# 21011 of 58490 completed
# 21097 of 58490 completed
# 21184 of 58490 completed
# 21276 of 58490 completed
# 21355 of 58490 completed
# 21452 of 58490 completed
# 21548 of 58490 completed
# 21643 of 58490 completed
# 21739 of 58490 completed
# 21835 of 58490 completed
# 21871 of 58490 completed
# 21889 of 58490 completed
# 21929 of 58490 completed
# 22027 of 58490 completed
# 22120 of 58490 completed
# 22214 of 58490 completed
# 22299 of 58490 completed
# 22386 of 58490 completed
# 22418 of 58490 completed
# 22497 of 58490 completed
# 22591 of 58490 completed
# 22688 of 58490 completed
# 22700 of 58490 completed
# 22798 of 58490 completed
# 22838 of 58490 completed
# 22901 of 58490 completed
# 22998 of 58490 completed
# 23084 of 58490 completed
# 23178 of 58490 completed
# 23264 of 58490 completed
# 23362 of 58490 completed
# 23400 of 58490 completed
# 23448 of 58490 completed
# 23481 of 58490 completed
# 23579 of 58490 completed
# 23597 of 58490 completed
# 23693 of 58490 completed
# 23789 of 58490 completed
# 23818 of 58490 completed
# 23914 of 58490 completed
# 23933 of 58490 completed
# 24026 of 58490 completed
# 24119 of 58490 completed
# 24157 of 58490 completed
# 24179 of 58490 completed
# 24250 of 58490 completed
# 24277 of 58490 completed
# 24350 of 58490 completed
# 24431 of 58490 completed
# 24526 of 58490 completed
# 24607 of 58490 completed
# 24677 of 58490 completed
# 24773 of 58490 completed
# 24859 of 58490 completed
# 24927 of 58490 completed
# 25016 of 58490 completed
# 25100 of 58490 completed
# 25168 of 58490 completed
# 25265 of 58490 completed
# 25351 of 58490 completed
# 25447 of 58490 completed
# 25529 of 58490 completed
# 25627 of 58490 completed
# 25692 of 58490 completed
# 25773 of 58490 completed
# 25827 of 58490 completed
# 25912 of 58490 completed
# 25995 of 58490 completed
# 26089 of 58490 completed
# 26126 of 58490 completed
# 26160 of 58490 completed
# 26254 of 58490 completed
# 26352 of 58490 completed
# 26449 of 58490 completed
# 26474 of 58490 completed
# 26569 of 58490 completed
# 26666 of 58490 completed
# 26740 of 58490 completed
# 26807 of 58490 completed
# 26902 of 58490 completed
# 26989 of 58490 completed
# 27029 of 58490 completed
# 27054 of 58490 completed
# 27152 of 58490 completed
# 27190 of 58490 completed
# 27222 of 58490 completed
# 27280 of 58490 completed
# 27368 of 58490 completed
# 27415 of 58490 completed
# 27482 of 58490 completed
# 27540 of 58490 completed
# 27627 of 58490 completed
# 27675 of 58490 completed
# 27759 of 58490 completed
# 27853 of 58490 completed
# 27945 of 58490 completed
# 28041 of 58490 completed
# 28120 of 58490 completed
# 28126 of 58490 completed
# 28191 of 58490 completed
# 28266 of 58490 completed
# 28363 of 58490 completed
# 28419 of 58490 completed
# 28516 of 58490 completed
# 28548 of 58490 completed
# 28604 of 58490 completed
# 28674 of 58490 completed
# 28760 of 58490 completed
# 28801 of 58490 completed
# 28833 of 58490 completed
# 28930 of 58490 completed
# 29007 of 58490 completed
# 29102 of 58490 completed
# 29167 of 58490 completed
# 29253 of 58490 completed
# 29325 of 58490 completed
# 29421 of 58490 completed
# 29510 of 58490 completed
# 29606 of 58490 completed
# 29704 of 58490 completed
# 29746 of 58490 completed
# 29772 of 58490 completed
# 29830 of 58490 completed
# 29911 of 58490 completed
# 30009 of 58490 completed
# 30063 of 58490 completed
# 30160 of 58490 completed
# 30257 of 58490 completed
# 30355 of 58490 completed
# 30397 of 58490 completed
# 30426 of 58490 completed
# 30453 of 58490 completed
# 30544 of 58490 completed
# 30633 of 58490 completed
# 30730 of 58490 completed
# 30760 of 58490 completed
# 30784 of 58490 completed
# 30881 of 58490 completed
# 30941 of 58490 completed
# 30974 of 58490 completed
# 31071 of 58490 completed
# 31167 of 58490 completed
# 31258 of 58490 completed
# 31353 of 58490 completed
# 31422 of 58490 completed
# 31449 of 58490 completed
# 31537 of 58490 completed
# 31632 of 58490 completed
# 31711 of 58490 completed
# 31778 of 58490 completed
# 31849 of 58490 completed
# 31946 of 58490 completed
# 32044 of 58490 completed
# 32112 of 58490 completed
# 32190 of 58490 completed
# 32226 of 58490 completed
# 32285 of 58490 completed
# 32377 of 58490 completed
# 32393 of 58490 completed
# 32413 of 58490 completed
# 32461 of 58490 completed
# 32548 of 58490 completed
# 32639 of 58490 completed
# 32658 of 58490 completed
# 32756 of 58490 completed
# 32845 of 58490 completed
# 32865 of 58490 completed
# 32963 of 58490 completed
# 33016 of 58490 completed
# 33073 of 58490 completed
# 33135 of 58490 completed
# 33233 of 58490 completed
# 33330 of 58490 completed
# 33425 of 58490 completed
# 33523 of 58490 completed
# 33571 of 58490 completed
# 33593 of 58490 completed
# 33675 of 58490 completed
# 33773 of 58490 completed
# 33814 of 58490 completed
# 33856 of 58490 completed
# 33933 of 58490 completed
# 34030 of 58490 completed
# 34091 of 58490 completed
# 34189 of 58490 completed
# 34222 of 58490 completed
# 34312 of 58490 completed
# 34339 of 58490 completed
# 34437 of 58490 completed
# 34534 of 58490 completed
# 34555 of 58490 completed
# 34582 of 58490 completed
# 34676 of 58490 completed
# 34774 of 58490 completed
# 34866 of 58490 completed
# 34963 of 58490 completed
# 35032 of 58490 completed
# 35130 of 58490 completed
# 35143 of 58490 completed
# 35161 of 58490 completed
# 35219 of 58490 completed
# 35317 of 58490 completed
# 35335 of 58490 completed
# 35360 of 58490 completed
# 35420 of 58490 completed
# 35518 of 58490 completed
# 35616 of 58490 completed
# 35661 of 58490 completed
# 35682 of 58490 completed
# 35712 of 58490 completed
# 35793 of 58490 completed
# 35877 of 58490 completed
# 35930 of 58490 completed
# 35989 of 58490 completed
# 36066 of 58490 completed
# 36157 of 58490 completed
# 36166 of 58490 completed
# 36214 of 58490 completed
# 36251 of 58490 completed
# 36313 of 58490 completed
# 36333 of 58490 completed
# 36423 of 58490 completed
# 36504 of 58490 completed
# 36593 of 58490 completed
# 36653 of 58490 completed
# 36659 of 58490 completed
# 36677 of 58490 completed
# 36773 of 58490 completed
# 36785 of 58490 completed
# 36873 of 58490 completed
# 36954 of 58490 completed
# 36965 of 58490 completed
# 37002 of 58490 completed
# 37099 of 58490 completed
# 37144 of 58490 completed
# 37234 of 58490 completed
# 37318 of 58490 completed
# 37356 of 58490 completed
# 37453 of 58490 completed
# 37551 of 58490 completed
# 37644 of 58490 completed
# 37741 of 58490 completed
# 37776 of 58490 completed
# 37800 of 58490 completed
# 37889 of 58490 completed
# 37910 of 58490 completed
# 37989 of 58490 completed
# 38087 of 58490 completed
# 38183 of 58490 completed
# 38200 of 58490 completed
# 38286 of 58490 completed
# 38302 of 58490 completed
# 38365 of 58490 completed
# 38437 of 58490 completed
# 38535 of 58490 completed
# 38629 of 58490 completed
# 38693 of 58490 completed
# 38777 of 58490 completed
# 38873 of 58490 completed
# 38965 of 58490 completed
# 38997 of 58490 completed
# 39032 of 58490 completed
# 39052 of 58490 completed
# 39087 of 58490 completed
# 39177 of 58490 completed
# 39210 of 58490 completed
# 39308 of 58490 completed
# 39371 of 58490 completed
# 39466 of 58490 completed
# 39557 of 58490 completed
# 39643 of 58490 completed
# 39740 of 58490 completed
# 39808 of 58490 completed
# 39857 of 58490 completed
# 39923 of 58490 completed
# 40021 of 58490 completed
# 40041 of 58490 completed
# 40060 of 58490 completed
# 40114 of 58490 completed
# 40212 of 58490 completed
# 40305 of 58490 completed
# 40321 of 58490 completed
# 40375 of 58490 completed
# 40407 of 58490 completed
# 40505 of 58490 completed
# 40588 of 58490 completed
# 40680 of 58490 completed
# 40698 of 58490 completed
# 40766 of 58490 completed
# 40785 of 58490 completed
# 40878 of 58490 completed
# 40958 of 58490 completed
# 40978 of 58490 completed
# 41066 of 58490 completed
# 41163 of 58490 completed
# 41250 of 58490 completed
# 41263 of 58490 completed
# 41276 of 58490 completed
# 41289 of 58490 completed
# 41387 of 58490 completed
# 41483 of 58490 completed
# 41557 of 58490 completed
# 41621 of 58490 completed
# 41718 of 58490 completed
# 41804 of 58490 completed
# 41859 of 58490 completed
# 41872 of 58490 completed
# 41934 of 58490 completed
# 42029 of 58490 completed
# 42079 of 58490 completed
# 42177 of 58490 completed
# 42269 of 58490 completed
# 42360 of 58490 completed
# 42456 of 58490 completed
# 42540 of 58490 completed
# 42603 of 58490 completed
# 42642 of 58490 completed
# 42740 of 58490 completed
# 42809 of 58490 completed
# 42889 of 58490 completed
# 42924 of 58490 completed
# 42975 of 58490 completed
# 43073 of 58490 completed
# 43151 of 58490 completed
# 43226 of 58490 completed
# 43291 of 58490 completed
# 43381 of 58490 completed
# 43438 of 58490 completed
# 43523 of 58490 completed
# 43621 of 58490 completed
# 43656 of 58490 completed
# 43705 of 58490 completed
# 43724 of 58490 completed
# 43802 of 58490 completed
# 43900 of 58490 completed
# 43994 of 58490 completed
# 44090 of 58490 completed
# 44186 of 58490 completed
# 44271 of 58490 completed
# 44369 of 58490 completed
# 44465 of 58490 completed
# 44563 of 58490 completed
# 44652 of 58490 completed
# 44732 of 58490 completed
# 44828 of 58490 completed
# 44859 of 58490 completed
# 44886 of 58490 completed
# 44949 of 58490 completed
# 45046 of 58490 completed
# 45123 of 58490 completed
# 45207 of 58490 completed
# 45302 of 58490 completed
# 45392 of 58490 completed
# 45490 of 58490 completed
# 45576 of 58490 completed
# 45674 of 58490 completed
# 45761 of 58490 completed
# 45811 of 58490 completed
# 45902 of 58490 completed
# 45952 of 58490 completed
# 46050 of 58490 completed
# 46125 of 58490 completed
# 46220 of 58490 completed
# 46249 of 58490 completed
# 46334 of 58490 completed
# 46358 of 58490 completed
# 46435 of 58490 completed
# 46530 of 58490 completed
# 46560 of 58490 completed
# 46599 of 58490 completed
# 46640 of 58490 completed
# 46680 of 58490 completed
# 46765 of 58490 completed
# 46815 of 58490 completed
# 46913 of 58490 completed
# 47010 of 58490 completed
# 47083 of 58490 completed
# 47151 of 58490 completed
# 47235 of 58490 completed
# 47247 of 58490 completed
# 47345 of 58490 completed
# 47443 of 58490 completed
# 47454 of 58490 completed
# 47530 of 58490 completed
# 47617 of 58490 completed
# 47628 of 58490 completed
# 47651 of 58490 completed
# 47745 of 58490 completed
# 47777 of 58490 completed
# 47867 of 58490 completed
# 47965 of 58490 completed
# 47987 of 58490 completed
# 48059 of 58490 completed
# 48123 of 58490 completed
# 48221 of 58490 completed
# 48317 of 58490 completed
# 48407 of 58490 completed
# 48496 of 58490 completed
# 48508 of 58490 completed
# 48605 of 58490 completed
# 48621 of 58490 completed
# 48674 of 58490 completed
# 48710 of 58490 completed
# 48765 of 58490 completed
# 48860 of 58490 completed
# 48922 of 58490 completed
# 48940 of 58490 completed
# 49017 of 58490 completed
# 49113 of 58490 completed
# 49129 of 58490 completed
# 49185 of 58490 completed
# 49275 of 58490 completed
# 49369 of 58490 completed
# 49458 of 58490 completed
# 49481 of 58490 completed
# 49531 of 58490 completed
# 49625 of 58490 completed
# 49720 of 58490 completed
# 49817 of 58490 completed
# 49915 of 58490 completed
# 50007 of 58490 completed
# 50077 of 58490 completed
# 50171 of 58490 completed
# 50204 of 58490 completed
# 50301 of 58490 completed
# 50397 of 58490 completed
# 50457 of 58490 completed
# 50531 of 58490 completed
# 50629 of 58490 completed
# 50726 of 58490 completed
# 50809 of 58490 completed
# 50887 of 58490 completed
# 50970 of 58490 completed
# 51067 of 58490 completed
# 51161 of 58490 completed
# 51258 of 58490 completed
# 51336 of 58490 completed
# 51363 of 58490 completed
# 51423 of 58490 completed
# 51521 of 58490 completed
# 51532 of 58490 completed
# 51619 of 58490 completed
# 51665 of 58490 completed
# 51762 of 58490 completed
# 51859 of 58490 completed
# 51955 of 58490 completed
# 52046 of 58490 completed
# 52142 of 58490 completed
# 52235 of 58490 completed
# 52329 of 58490 completed
# 52414 of 58490 completed
# 52497 of 58490 completed
# 52595 of 58490 completed
# 52684 of 58490 completed
# 52782 of 58490 completed
# 52860 of 58490 completed
# 52909 of 58490 completed
# 53004 of 58490 completed
# 53092 of 58490 completed
# 53184 of 58490 completed
# 53282 of 58490 completed
# 53380 of 58490 completed
# 53424 of 58490 completed
# 53519 of 58490 completed
# 53572 of 58490 completed
# 53667 of 58490 completed
# 53759 of 58490 completed
# 53857 of 58490 completed
# 53914 of 58490 completed
# 54012 of 58490 completed
# 54102 of 58490 completed
# 54199 of 58490 completed
# 54265 of 58490 completed
# 54363 of 58490 completed
# 54440 of 58490 completed
# 54463 of 58490 completed
# 54559 of 58490 completed
# 54655 of 58490 completed
# 54748 of 58490 completed
# 54833 of 58490 completed
# 54894 of 58490 completed
# 54964 of 58490 completed
# 54988 of 58490 completed
# 55081 of 58490 completed
# 55100 of 58490 completed
# 55179 of 58490 completed
# 55261 of 58490 completed
# 55358 of 58490 completed
# 55453 of 58490 completed
# 55543 of 58490 completed
# 55577 of 58490 completed
# 55616 of 58490 completed
# 55705 of 58490 completed
# 55758 of 58490 completed
# 55824 of 58490 completed
# 55854 of 58490 completed
# 55952 of 58490 completed
# 56037 of 58490 completed
# 56101 of 58490 completed
# 56171 of 58490 completed
# 56268 of 58490 completed
# 56298 of 58490 completed
# 56307 of 58490 completed
# 56405 of 58490 completed
# 56431 of 58490 completed
# 56527 of 58490 completed
# 56542 of 58490 completed
# 56605 of 58490 completed
# 56634 of 58490 completed
# 56686 of 58490 completed
# 56750 of 58490 completed
# 56805 of 58490 completed
# 56903 of 58490 completed
# 56914 of 58490 completed
# 57011 of 58490 completed
# 57087 of 58490 completed
# 57182 of 58490 completed
# 57276 of 58490 completed
# 57369 of 58490 completed
# 57457 of 58490 completed
# 57477 of 58490 completed
# 57510 of 58490 completed
# 57579 of 58490 completed
# 57675 of 58490 completed
# 57729 of 58490 completed
# 57768 of 58490 completed
# 57863 of 58490 completed
# 57950 of 58490 completed
# 58048 of 58490 completed
# 58075 of 58490 completed
# 58171 of 58490 completed
# 58253 of 58490 completed
# 58349 of 58490 completed
# 58440 of 58490 completed

# %%
act = pred_rating.pivot(
    index='movieId',
    columns='userId',
    values='rating'
).fillna(0)

# %%
sr_test_list =act.unstack().reset_index(name="rating").set_index("movieId")
sr_test_list = sr_test_list[sr_test_list.rating>0]

# %%
sr_test_rem = sr_test_list

# %%
#Filling the actual values in our user-item matrix to 0 so that the movies they have already rated
# are not recommended to them again.
a = list(sr_test_rem.index)
b = list(sr_test_rem.loc[:, "userId"])

for i in range(len(a)):
    pr.at[a[i],b[i]]=0

# %%
pr.to_csv("predictions.csv", sep=',')

# %%
act.to_csv("actual.csv")

# %%
rec = pr.unstack().reset_index(name="rating")

# %% [markdown]
# To make recommendations, we sort the item-user matrix for every user and pick the top 5 highest recommendations predicted for a user and then compute the coverage.

# %%
rec_sorted = rec.sort_values(by=['userId','rating'],ascending = [True,False])
rec_sorted_top_10 = rec_sorted.groupby('userId').head(10)
rec_sorted_top_10.head()
# Out:
#      userId  movieId    rating
# 574     903    48127  4.000000
# 74      903      746  3.821539
# 338     903     4338  3.682377
# 573     903    47972  3.507663
# 774     903    97005  3.498344

# %% [markdown]
# We compute catalog coverage as the percentage of movies in the sample present in the top-5 recommendations made by our model.

# %%
(len(rec_sorted_top_10['movieId'].drop_duplicates())/len(rec_sorted['movieId'].drop_duplicates()))*100
# Out:
# 24.882075471698112

# %% [markdown]
# Our catalog coverage on the movies set is nearly 25%. This can be significantly improved by adding the same business rule we added to our ALS model. We now look at the distribution of the number of ratings of the movies recommended by our model.

# %%
movie_dist = pred_rating.groupby('movieId').size().reset_index(name='counts')
movie_dist = movie_dist.merge(rec_sorted_top_10,on="movieId")
movie_dist['counts'].describe()
# Out:
# count    990.000000
# mean       7.242424
# std        8.412628
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        9.000000
# max       86.000000
# Name: counts, dtype: float64

# %% [markdown]
# From the distribution, we see that 75% of the recommended movies have only been rated by atmost 9% of the users in the sampled data, whereas there are movies with even a high number of ratings (rated by 86 of the 100 users in the sample). Thus, we are able to recommend movies with low and high number of ratings, hence accomplishing our business objective of being able to recommend even movies with low number of ratings to improve discovery.
#
# We assume that these results are reproducible on a larger dataset (which we were unable to test due to the unfeasibility of filling out the entire matrix for a larger sample - it took 1 hour to just run the code for this very small sample). We assume that building this model for a larger dataset combined with adding our business rule to the model will produce recommendations with high coverage and discoverability.
